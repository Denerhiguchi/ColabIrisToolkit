# %% [markdown]
# <a href="https://colab.research.google.com/github/Denerhiguchi/ColabIrisToolkit/blob/main/treino_de_software.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("olá mundo")
# Out:
# olá mundo

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install numpy

# %%
import numpy as np
matriz = np.array([[1,2,3],[4,5,6]])
print(matriz)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %%
import matplotlib.pyplot as plt
#Criando um grafico simples
x =[1,2,3,4]
y =[10,20,25,30]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('gráfico simples')
plt.show()
